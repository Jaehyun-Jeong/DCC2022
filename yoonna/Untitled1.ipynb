# %%
from os import listdir 



root_path = r"C:\Users\user\DCC2022\dataset"

# %%
listdir(root_path)
# Out:
# ['L2_10',
#  'L2_12',
#  'L2_15',
#  'L2_20',
#  'L2_21',
#  'L2_24',
#  'L2_25',
#  'L2_27',
#  'L2_3',
#  'L2_30',
#  'L2_33',
#  'L2_34',
#  'L2_39',
#  'L2_40',
#  'L2_41',
#  'L2_44',
#  'L2_45',
#  'L2_46',
#  'L2_50',
#  'L2_52']

# %%
data_dict = {}

for class_name in listdir(root_path):
    data_dict[class_name] = listdir(root_path + '/' + class_name)

# %%
test_percentage = 0.2
train_percentage = 0.8

train_len = int(len(data_dict['L2_10']) * train_percentage)

data_dict['L2_10'][:train_len]
# Out:
# ['aamhfbsxjoqkqsxnnpoy.jpg',
#  'aatdcomdixgejmiibsft.jpg',
#  'aatmmprdzkzdkbfcslkx.jpg',
#  'abaoovbyxzqodvhoasko.jpg',
#  'abymagsohyagiheolkhk.jpg',
#  'abzsvhshnhwujgwfyphe.jpg',
#  'abzvzrtojegizjimyntg.jpg',
#  'acqylihnzmuhgsunsiql.jpg',
#  'actkjeagmzwopnoewwxo.jpg',
#  'adexiemcbuovefubehxd.jpg',
#  'adifywyfmtduwlbotdky.jpg',
#  'adketuwinjndjaqrrzho.jpg',
#  'adktajhgfxnovqziuvkp.jpg',
#  'adqgcyopecgxiqvcswgx.jpg',
#  'adzihlnlmguqfbmnlexu.jpg',
#  'aegkmchbtjysohrncydf.jpg',
#  'aeigyfmtyxgrmojjuyvl.jpg',
#  'aeypibgixadxeaptezwc.jpg',
#  'afalpcuekknfvfhiysjg.jpg',
#  'afcoqgsquisapemvjpgs.jpg',
#  'afoeukiszwwkpngpxgwa.jpg',
#  'afxaixauzhvviaxboajt.jpg',
#  'agncxlfheqbbavhlqdxo.jpg',
#  'ahlxrmxletwkejbdasut.jpg',
#  'ahtgfmagrlwtfboksyey.jpg',
#  'ahzqmrewtnokpmmqbyqa.jpg',
#  'aipjgfeuwfmcbtzqdlie.jpg',
#  'airwdxvrtemeyyhotzol.jpg',
#  'aitpcvojbatzslqgfglz.jpg',
#  'ajqnypdatowmrkpwxlrd.jpg',
#  'aknjihylvztqcfrxdwcs.jpg',
#  'akplcwhqpowurnkctouy.jpg',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 listdir(train_dict)
#
# TypeError: listdir: path should be string, bytes, os.PathLike or None, not list

# %%
# Out:
# ['.ipynb_checkpoints', '221015_1.ipynb', '221015_2.ipynb', '221015_3.ipynb', 'README.md', 'Untitled.ipynb', 'Untitled1.ipynb']
